# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("student-mat.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#check the null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# dtype: int64

# %% [markdown]
# We don’t have any duplicate or missing values, and the following codes will provide a good data checking.
# There are 33 attributes and 395 rows

# %% [markdown]
# Exploring the Data

# %%
for col in list(df.columns):
    print(f"Categories in {col} attribute are {df[col].unique()}")
# Out:
# Categories in school attribute are ['GP' 'MS']
# Categories in sex attribute are ['F' 'M']
# Categories in age attribute are [18 17 15 16 19 22 20 21]
# Categories in address attribute are ['U' 'R']
# Categories in famsize attribute are ['GT3' 'LE3']
# Categories in Pstatus attribute are ['A' 'T']
# Categories in Medu attribute are [4 1 3 2 0]
# Categories in Fedu attribute are [4 1 2 3 0]
# Categories in Mjob attribute are ['at_home' 'health' 'other' 'services' 'teacher']
# Categories in Fjob attribute are ['teacher' 'other' 'services' 'health' 'at_home']
# Categories in reason attribute are ['course' 'other' 'home' 'reputation']
# Categories in guardian attribute are ['mother' 'father' 'other']
# Categories in traveltime attribute are [2 1 3 4]
# Categories in studytime attribute are [2 3 1 4]
# Categories in failures attribute are [0 3 2 1]
# Categories in schoolsup attribute are ['yes' 'no']
# Categories in famsup attribute are ['no' 'yes']
# ...

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != "object"]
categorical_features = [feature for feature in df.columns if df[feature].dtype == "object"]
print(f"Number of numerical features in the dataset are {len(numeric_features)}")
print(f"numeric Features : {numeric_features}")
print(f"Number of categorical features in the dataset are {len(categorical_features)}")
print(f"Categorical Features : {categorical_features}")
# Out:
# Number of numerical features in the dataset are 16
# numeric Features : ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
# Number of categorical features in the dataset are 17
# Categorical Features : ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']

# %%
f,ax=plt.subplots(1,2,figsize=(8,6))


# Create a countplot of the 'gender' column and add labels to the bars
sns.countplot(x=df['sex'],data=df,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)

# Set font size of x-axis and y-axis labels and tick labels
ax[0].set_xlabel('Gender', fontsize=14)
ax[0].set_ylabel('Count', fontsize=14)
ax[0].tick_params(labelsize=14)

# Create a pie chart of the 'gender' column and add labels to the slices
plt.pie(x=df['sex'].value_counts(),labels=['Male','Female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'], textprops={'fontsize': 14})

# Display the plot
plt.show()

# %%
figsize=(18,18)
plt.subplot(1, 3, 1) 
plt.title('G1 SCORES') 
sns.violinplot(y='G1',data=df,color='red',linewidth=1) 
plt.subplot(1, 3, 2) 
plt.title('G2 SCORES') 
sns.violinplot(y='G2',data=df,color='green',linewidth=1) 
plt.subplot(1, 3, 3) 
plt.title('G3 SCORES') 
sns.violinplot(y='G3',data=df,color='blue',linewidth=1) 
plt.show()

# %% [markdown]
# It can be clearly seen that most of the students score between 7.5 to 10 in G1, 10 in G2 and 10 in G3 out of 20

# %%
plt.subplots(1,2)
plt.subplot(121)
sns.histplot(data=df, x='G3', kde=True)

plt.subplot(122)
sns.histplot(data=df, x='G3',kde=True, hue='sex')
# Out:
# <AxesSubplot:xlabel='G3', ylabel='Count'>

# %% [markdown]
# It can be seen that most of the girls and boys have marks between 7.5 to 12.5, but more boys have marks betweem 15 to 20 than girls

# %%
# Set figure size
plt.rcParams['figure.figsize'] = (12, 9)

# First row of pie charts
plt.subplot(2, 3, 1)
size = df['sex'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']
plt.pie(size, colors=color, labels=labels, autopct='%.2f%%')
plt.title('Gender', fontsize=20)
plt.axis('off')

plt.subplot(2, 3, 2)
size = df['age'].value_counts()
labels = 'Group 15', 'Group 16', 'Group 17', 'Group 18', 'Group 19', 'Group 20','Group 21', 'Group 22'
color = ['red', 'green', 'blue', 'cyan', 'orange', 'purple' ,'magenta','yellow']
plt.pie(size, colors=color, labels=labels, autopct='%.2f%%')
plt.title('Age', fontsize=20)
plt.axis('off')

plt.subplot(2, 3, 3)
size = df['studytime'].value_counts()
labels ='less than 2', '2 to 5', '5 to 10', 'more than 10'
color = ['red', 'green','yellow','orange']
plt.pie(size, colors=color, labels=labels, autopct='%.2f%%')
plt.title('Study Time in Hours', fontsize=20)
plt.axis('off')

# Second row of pie charts
plt.subplot(2, 3, 4)
size = df['traveltime'].value_counts()
labels = 'less than 15', '15 to 30','30 to 60','more than 60'
color = ['red', 'green','blue','orange']
plt.pie(size, colors=color, labels=labels, autopct='%.2f%%')
plt.title('Travel Time in Minutes', fontsize=20)
plt.axis('off')

plt.subplot(2, 3, 5)
size = df['failures'].value_counts()
labels = '1', "2", '3', '4 or more'
color = ['red', 'green', 'blue', 'cyan']
plt.pie(size, colors=color, labels=labels, autopct='%.2f%%')
plt.title('Failures in Exams', fontsize=20)
plt.axis("off")
# Out:
# (-1.25, 1.25, -1.25, 1.25)

# %% [markdown]
# There are almost equal number of male and female students
# Students of Age from 15 to 22 are studying this subject with students between 15 to 18 having almost same percent (between 20- 26)
# Half off the students study for less than 2 hours
#
# 65% students live close to the college with travel time of less than 15 minutes
#
# 3/4 th of the students have failed in Math 1 time

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
corr=df.corr()
sns.heatmap(corr, annot=True,cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation_cols(data, threshold):
    data=data.drop("G3", axis=1)
    col_corr = set()
    corr_matrix = data.corr()
    for i in range(corr_matrix.shape[0]):
        for j in range(i):
            if corr_matrix.iloc[i, j] > threshold:
                col_name = corr_matrix.columns[j]
                col_corr.add(col_name)

    return col_corr

ans = correlation_cols(df, 0.60)

print(f"Columns with highest correlation (threshold 60%) are {ans}. Total number of columns are {len(ans)}.")
# Out:
# Columns with highest correlation (threshold 60%) are {'G1', 'Dalc', 'Medu'}. Total number of columns are 3.
